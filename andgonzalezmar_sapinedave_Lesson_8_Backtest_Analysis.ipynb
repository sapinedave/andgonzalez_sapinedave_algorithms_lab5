# %%
bt = get_backtest('5e866b22c4dc83459fdca714')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:21|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-11-10</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>22</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>3.664%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>6.926%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.334%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.72</td>
#     </tr>
#     <tr>
# ...
